# %% [markdown]
# ### In this notebook I'm modeling the effect of tweezers on an ion as the mass of that ion being reduced

# %%
import numpy as np
from scipy import constants
import tabulate
import pandas as pd
import matplotlib.pyplot as plt
# importing Vikrams functions
import sys
sys.path.insert(0,"/Users/ritika/SQRL_Rithi_python/XTalkRobustMS/tools")
from IonChainTools import *

# %%
#Constants in SI units
eps0 = constants.epsilon_0 
m = 2.413344e-24
c = constants.c
e = constants.e
hbar = constants.hbar
pi = np.pi

# %%
fig,ax = plt.subplots(1,1)
visualizeAxialMode(3,0,ax,head_size = 0.005,masses=[1,1,1])
ax.set_ylim(-0.04,0.04)
ax.set_xlim(-2,2)
ax.legend()
plt.show()

# %%
print("below are the eigenvectors for the 0,1,2 modes when the ions have the same mass")
print(calcAxialModes(3,masses=[1,1,1])[0])
print(calcAxialModes(3,masses=[1,1,1])[1])
print(calcAxialModes(3,masses=[1,1,1])[2])


print("  ")
print("below are the eigenvectors for the 0,1,2 modes when the ion on the left has half the mass of the other two ions")
print(calcAxialModes(3,masses=[0.5,1,1])[0])
print(calcAxialModes(3,masses=[0.5,1,1])[1])
print(calcAxialModes(3,masses=[0.5,1,1])[2])
# Out:
# below are the eigenvectors for the 0,1,2 modes when the ions have the same mass
# (0.9999999999999998, array([0.57735027, 0.57735027, 0.57735027]))
# (1.732050807568877, array([ 7.07106781e-01, -6.06970460e-14, -7.07106781e-01]))
# (2.408318915758459, array([-0.40824829,  0.81649658, -0.40824829]))
#
# below are the eigenvectors for the 0,1,2 modes when the ion on the left has half the mass of the other two ions
# (1.0791413915027463, array([0.48638969, 0.59408841, 0.64069028]))
# (2.0103646841693106, array([ 0.66676813,  0.40307997, -0.62685469]))
# (2.719170405434389, array([-0.85684954,  0.49733003, -0.13591062]))

# %%
fig,ax = plt.subplots(1,1)
visualizeAxialMode(3,1,ax,head_size = 0.005,masses=[1,1,1])
ax.set_ylim(-0.04,0.04)
ax.set_xlim(-2,2)
ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(1,1)
visualizeAxialMode(3,2,ax,head_size = 0.005,masses=[1,1,1])
ax.set_ylim(-0.04,0.04)
ax.set_xlim(-2,2)
ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(1,1)
visualizeAxialMode(3,0,ax,head_size = 0.005,masses=[10,1,1])
ax.set_ylim(-0.04,0.04)
ax.set_xlim(-2,2)
ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(1,1)
visualizeAxialMode(3,1,ax,head_size = 0.005,masses=[10,1,1])
ax.set_ylim(-0.04,0.04)
ax.set_xlim(-2,2)
ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(1,1)
visualizeAxialMode(3,2,ax,head_size = 0.005,masses=[10,1,1])
ax.set_ylim(-0.04,0.04)
ax.set_xlim(-2,2)
ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(1,1)
visualizeAxialMode(3,0,ax,head_size = 0.005,masses=[100,1,1])
ax.set_ylim(-0.04,0.04)
ax.set_xlim(-2,2)
ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(1,1)
visualizeAxialMode(3,1,ax,head_size = 0.005,masses=[100,1,1])
ax.set_ylim(-0.04,0.04)
ax.set_xlim(-2,2)
#ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(1,1)
visualizeAxialMode(3,0,ax,head_size = 0.005,masses=[0.5,1,1])
ax.set_ylim(-0.04,0.04)
ax.set_xlim(-2,2)

ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(1,1)
visualizeAxialMode(3,1
                   
                   
                   
                   ,ax,head_size = 0.005,masses=[1,1,1])
ax.set_ylim(-0.04,0.04)
ax.set_xlim(-2,2)
fig.set_dpi(600)
ax.set_xlabel("z-position",fontsize = 15)
ax.set_ylabel("y-position",fontsize = 15)
ax.set_title("Center of Mass Mode -- No Optical Tweezers",fontsize = 20)
plt.show()

# %%
fig,ax = plt.subplots(1,1)
visualizeAxialMode(3,2,ax,head_size = 0.005,masses=[0.5,1,1])
ax.set_ylim(-0.04,0.04)
ax.set_xlim(-2,2)
fig.set_dpi(600)
ax.legend()
ax.set_xlabel("z-position",fontsize = 15)
ax.set_ylabel("y-position",fontsize = 15)
ax.set_title("With Optical Tweezers",fontsize = 20)
plt.show()
